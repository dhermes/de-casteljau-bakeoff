# %%
import bakeoff_opt
import seaborn

import nb_helpers

seaborn.set()

# %%
seed = 798031893
functions = (
    bakeoff_opt.forall1,
    bakeoff_opt.spread1,
    bakeoff_opt.serial,
    bakeoff_opt.vs_algorithm64,
)
results_cache = nb_helpers.get_timeit_results()

# %%
num_values_list = (3, 9, 33, 129, 513)
nb_helpers.plot_data_values(
    get_ipython, results_cache, functions, 2, num_values_list, seed
)

# %%
num_values_list = (3, 9, 33, 129, 513)
nb_helpers.plot_data_values(
    get_ipython, results_cache, functions, 4, num_values_list, seed
)

# %%
num_values_list = (3, 9, 33, 129, 513)
nb_helpers.plot_data_values(
    get_ipython, results_cache, functions, 8, num_values_list, seed
)

# %%
num_values_list = (3, 9, 33, 129, 513)
nb_helpers.plot_data_values(
    get_ipython, results_cache, functions, 16, num_values_list, seed
)

# %%
num_values_list = (3, 9, 33, 129, 513)
nb_helpers.plot_data_values(
    get_ipython, results_cache, functions, 32, num_values_list, seed
)

# %%
num_values_list = (3, 9, 33, 129, 513)
nb_helpers.plot_data_values(
    get_ipython, results_cache, functions, 64, num_values_list, seed
)

# %%
nb_helpers.store_timeit_results(results_cache)
